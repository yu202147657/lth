# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# define constants and other global variables
label_size = 28
tick_size = 20
title_size = 40
line_width = 3

# %%
df = pd.read_csv('mnist_lenet_300_100_IMP.csv', sep='\t')
alpha = df.iloc[:,0]
accuracy = df.iloc[:,1]

train_error = abs(accuracy.subtract(100))
# Out:
# 0     0.031662
# 1     1.646667
# 2     9.701668
# 3    23.805000
# 4    31.513336
# 5    20.190002
# 6     5.989998
# 7     1.118332
# 8     0.023331
# 9     0.000000
# Name: 100.0, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15, 10))

ax.plot(alpha, train_error, linewidth=line_width, c='C0') #, marker = 'o'

plt.title("LeNet (MNIST)", fontsize=title_size)
ax.tick_params(axis='both', labelsize=tick_size)

ax.set_xlabel("Interpolation", fontsize=label_size)
ax.set_ylabel("Train Error (%)", fontsize=label_size)

ax.set_ylim([0, 100])

plt.show()
