# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# define constants and other global variables
label_size = 28
tick_size = 20
title_size = 40
line_width = 3

# %%
df = pd.read_csv('mnist_lenet_300_100_IMP.csv', sep='\t', header=None)
alpha = df.iloc[:,0]
train_error = df.iloc[:,1]

# %%
fig, ax = plt.subplots(figsize=(15, 10))

ax.plot(alpha, train_error, linewidth=line_width, c='C0') #, marker = 'o'

plt.title("LeNet (MNIST)", fontsize=title_size)
ax.tick_params(axis='both', labelsize=tick_size)

ax.set_xlabel("Interpolation", fontsize=label_size)
ax.set_ylabel("Train Error (%)", fontsize=label_size)

ax.set_ylim([0, 100])

plt.show()

# %%
df = pd.read_csv('cifar_resnet_20_IMP.csv', sep='\t', header=None)
alpha = df.iloc[:,0]
train_error = df.iloc[:,1]

fig, ax = plt.subplots(figsize=(15, 10))

ax.plot(alpha, train_error, linewidth=line_width, c='C0') #, marker = 'o'

plt.title("ResNet20 (CIFAR10)", fontsize=title_size)
ax.tick_params(axis='both', labelsize=tick_size)

ax.set_xlabel("Interpolation", fontsize=label_size)
ax.set_ylabel("Train Error (%)", fontsize=label_size)

ax.set_ylim([0, 100])

plt.show()
# Out:
# 0      0.423998
# 1     16.796000
# 2     80.875999
# 3     87.959999
# 4     88.921997
# 5     89.318001
# 6     89.846001
# 7     89.026001
# 8     72.585999
# 9     17.232000
# 10     0.375998
# Name: 1, dtype: float64

# %%
df = pd.read_csv('resnet20_GM.csv', sep='\t', header=None)
alpha = df.iloc[:,0]
train_error = df.iloc[:,1]


fig, ax = plt.subplots(figsize=(15, 10))

ax.plot(alpha, train_error, linewidth=line_width, c='C0') #, marker = 'o'

plt.title("ResNet (CIFAR10) - Gem Miner", fontsize=title_size)
ax.tick_params(axis='both', labelsize=tick_size)

ax.set_xlabel("Interpolation", fontsize=label_size)
ax.set_ylabel("Train Error (%)", fontsize=label_size)

ax.set_ylim([0, 100])

plt.show()

# %%
df = pd.read_csv('resnet20_EP.csv', sep='\t', header=None)
alpha = df.iloc[:,0]
train_error = df.iloc[:,1]


fig, ax = plt.subplots(figsize=(15, 10))

ax.plot(alpha, train_error, linewidth=line_width, c='C0') #, marker = 'o'

plt.title("ResNet (CIFAR10) - EP", fontsize=title_size)
ax.tick_params(axis='both', labelsize=tick_size)

ax.set_xlabel("Interpolation", fontsize=label_size)
ax.set_ylabel("Train Error (%)", fontsize=label_size)

ax.set_ylim([0, 100])

plt.show()
